# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))

# %%
# !git clone https://github.com/ignitedone/chess-move-predictor.git
# %cd chess-move-predictor
# !pip install -q -r requirements.txt

# %%
# !mkdir -p data/processed
# !cp /kaggle/input/datasets/igni1277/chess-move-predictor-tokenized/*.npy data/processed/
# !ls -la data/processed/
# !ls data/tokenizer/

# %%
TARGET_EPOCH = 5
MAX_TRAIN_SECONDS = 8 * 60 * 60

# %%
# !mkdir -p weights
# !cp /kaggle/input/chess-move-predictor-checkpoint/chess_transformer_*.pt weights/ 2>/dev/null || cp /kaggle/input/datasets/igni1277/chess-move-predictor-checkpoint/chess_transformer_*.pt weights/
# !ls weights/

# %%
from src.config import get_config
from src.train import train_model

config = get_config()
config["max_epochs"] = TARGET_EPOCH
config["max_train_seconds"] = MAX_TRAIN_SECONDS

train_model(config)
